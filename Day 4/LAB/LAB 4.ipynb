# %% [markdown]
# # LAB 4

# %% [markdown]
# ## Q1) Create a Vehicle class with name, max_speed and mileage instance attributes.

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

vehicle1 = Vehicle("BMW", 240, 18)
print(f"The name of vehicle is : {vehicle1.name}")
print(f"The max speed of the vehicle is : {vehicle1.max_speed}")
print(f"The mileage of the vehicle is : {vehicle1.mileage}")
# Out:
# The name of vehicle is : BMW
# The max speed of the vehicle is : 240
# The mileage of the vehicle is : 18

# %% [markdown]
# ## Q2) Create a child class Bus that will inherit all of the attributes and methods of the Vehicle class.

# %%
class Bus(Vehicle):
    pass

bus1 = Bus("Volvo", 180, 12)
print(f"The name of Bus is : {bus1.name}")
print(f"The max speed of the Bus is : {bus1.max_speed}")
print(f"The mileage of the Bus is : {bus1.mileage}")
# Out:
# The name of Bus is : Volvo
# The max speed of the Bus is : 180
# The mileage of the Bus is : 12

# %% [markdown]
# ## Q3) Add a function seating_capacity to the vehicle class that takes as an argument the capacity of the vehicle and returns the following formatted string "The seating capacity of a {<vehicle_name>} is {capacity} passengers"

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

vehicle1 = Vehicle("BMW", 240, 18)
print(vehicle1.seating_capacity(5))
# Out:
# The seating capacity of a BMW is 5 passengers

# %% [markdown]
# ## Q4) override the function seating_capacity in the Bus class to give the capacity argument a default value of 50

# %%
class Bus(Vehicle):
    def seating_capacity(self, capacity=50):
        return f"The seating capacity of a {self.name} Bus is {capacity} passengers"

bus1 = Bus("Volvo", 180, 12)
print(bus1.seating_capacity())
print(bus1.seating_capacity(100))
# Out:
# The seating capacity of a Volvo Bus is 50 passengers
# The seating capacity of a Volvo Bus is 100 passengers

# %% [markdown]
# ## Q5)  Add an instance variable to the Bus class called capacity and give it a default value of 50.

# %%
class Bus(Vehicle):
    def __init__(self, name, max_speed, mileage, capacity=50):
        super().__init__(name, max_speed, mileage)
        self.capacity = capacity

    def seating_capacity(self):
        return f"The seating capacity of a {self.name} Bus is {self.capacity} passengers"

bus1 = Bus("Volvo", 180, 12)
print(bus1.seating_capacity())
bus2 = Bus("Toyota", 200, 15, 60)
print(bus2.seating_capacity())
# Out:
# The seating capacity of a Volvo Bus is 50 passengers
# The seating capacity of a Toyota Bus is 60 passengers

# %% [markdown]
# ## Q6) Create a function fare() in the Bus class that calculates the renting fare of the bus per day according to the following equation. Fare = capacity *100

# %%
class Bus(Vehicle):
    def __init__(self, name, max_speed, mileage, capacity=50):
        super().__init__(name, max_speed, mileage)
        self.capacity = capacity

    def seating_capacity(self):
        return f"The seating capacity of a {self.name} Bus is {self.capacity} passengers"

    def fare(self):
        return self.capacity * 100

bus1 = Bus("Volvo", 180, 12)
print(f"the renting fare of the {bus1.name} bus per day is {bus1.fare()}$") 
bus2 = Bus("Toyota", 200, 15, 60)
print(f"the renting fare of the {bus2.name} bus per day is {bus2.fare()}$")
# Out:
# the renting fare of the Volvo bus per day is 5000$
# the renting fare of the Toyota bus per day is 6000$

# %% [markdown]
# # Putting it all together

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

    
class Bus(Vehicle):
    def __init__(self, name, max_speed, mileage, capacity=50):
        super().__init__(name, max_speed, mileage)
        self.capacity = capacity

    def seating_capacity(self):
        return f"The seating capacity of a {self.name} Bus is {self.capacity} passengers"

    def fare(self):
        return self.capacity * 100
    

vehicle1 = Vehicle("BMW", 240, 18)
print(vehicle1.seating_capacity(5))
print("--------------------------")
bus1 = Bus("Volvo", 180, 12)
print(f"the renting fare of the {bus1.name} bus per day is {bus1.fare()}$") 
bus2 = Bus("Toyota", 200, 15, 60)
print(f"the renting fare of the {bus2.name} bus per day is {bus2.fare()}$")
# Out:
# The seating capacity of a BMW is 5 passengers
# --------------------------
# the renting fare of the Volvo bus per day is 5000$
# the renting fare of the Toyota bus per day is 6000$
